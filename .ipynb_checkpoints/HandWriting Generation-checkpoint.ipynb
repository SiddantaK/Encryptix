# %%
import opendatasets as od

od.download("https://www.kaggle.com/datasets/landlord/handwriting-recognition")
# Out:
# Skipping, found downloaded files in "./handwriting-recognition" (use force=True to force download)

# %%
import opendatasets as od

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
import random
# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('./handwriting-recognition/'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# ./handwriting-recognition/written_name_test_v2.csv
# ./handwriting-recognition/written_name_validation_v2.csv
# ./handwriting-recognition/written_name_train_v2.csv
# ./handwriting-recognition/test_v2/test/TEST_21753.jpg
# ./handwriting-recognition/test_v2/test/TEST_30886.jpg
# ./handwriting-recognition/test_v2/test/TEST_11690.jpg
# ./handwriting-recognition/test_v2/test/TEST_9837.jpg
# ./handwriting-recognition/test_v2/test/TEST_31540.jpg
# ./handwriting-recognition/test_v2/test/TEST_27322.jpg
# ./handwriting-recognition/test_v2/test/TEST_28011.jpg
# ./handwriting-recognition/test_v2/test/TEST_11848.jpg
# ./handwriting-recognition/test_v2/test/TEST_37131.jpg
# ./handwriting-recognition/test_v2/test/TEST_38202.jpg
# ./handwriting-recognition/test_v2/test/TEST_23144.jpg
# ./handwriting-recognition/test_v2/test/TEST_34438.jpg
# ./handwriting-recognition/test_v2/test/TEST_33357.jpg
# ./handwriting-recognition/test_v2/test/TEST_13087.jpg
# ./handwriting-recognition/test_v2/test/TEST_32049.jpg
# ./handwriting-recognition/test_v2/test/TEST_14930.jpg
# ./handwriting-recognition/test_v2/test/TEST_25535.jpg
# ./handwriting-recognition/test_v2/test/TEST_12399.jpg
# ./handwriting-recognition/test_v2/test/TEST_2962.jpg
# ./handwriting-recognition/test_v2/test/TEST_35726.jpg
# ./handwriting-recognition/test_v2/test/TEST_15390.jpg
# ./handwriting-recognition/test_v2/test/TEST_13939.jpg
# ./handwriting-recognition/test_v2/test/TEST_35040.jpg
# ./handwriting-recognition/test_v2/test/TEST_25253.jpg
# ./handwriting-recognition/test_v2/test/TEST_33431.jpg
# ./handwriting-recognition/test_v2/test/TEST_23622.jpg
# ./handwriting-recognition/test_v2/test/TEST_37657.jpg
# ./handwriting-recognition/test_v2/test/TEST_26982.jpg
# ./handwriting-recognition/test_v2/test/TEST_38564.jpg
# ./handwriting-recognition/test_v2/test/TEST_17587.jpg
# ./handwriting-recognition/test_v2/test/TEST_9189.jpg
# ./handwriting-recognition/test_v2/test/TEST_0813.jpg
# ./handwriting-recognition/test_v2/test/TEST_27444.jpg
# ./handwriting-recognition/test_v2/test/TEST_30138.jpg
# ./handwriting-recognition/test_v2/test/TEST_16841.jpg
# ./handwriting-recognition/test_v2/test/TEST_28777.jpg
# ./handwriting-recognition/test_v2/test/TEST_29469.jpg
# ./handwriting-recognition/test_v2/test/TEST_31226.jpg
# ./handwriting-recognition/test_v2/test/TEST_36549.jpg
# ./handwriting-recognition/test_v2/test/TEST_21035.jpg
# ./handwriting-recognition/test_v2/test/TEST_8297.jpg
# ./handwriting-recognition/test_v2/test/TEST_16699.jpg
# ./handwriting-recognition/test_v2/test/TEST_26996.jpg
# ./handwriting-recognition/test_v2/test/TEST_37643.jpg
# ./handwriting-recognition/test_v2/test/TEST_0807.jpg
# ./handwriting-recognition/test_v2/test/TEST_17593.jpg
# ./handwriting-recognition/test_v2/test/TEST_38570.jpg
# ./handwriting-recognition/test_v2/test/TEST_27450.jpg
# ./handwriting-recognition/test_v2/test/TEST_28763.jpg
# ./handwriting-recognition/test_v2/test/TEST_16855.jpg
# ./handwriting-recognition/test_v2/test/TEST_18878.jpg
# ./handwriting-recognition/test_v2/test/TEST_31232.jpg
# ./handwriting-recognition/test_v2/test/TEST_8283.jpg
# ./handwriting-recognition/test_v2/test/TEST_21021.jpg
# ./handwriting-recognition/test_v2/test/TEST_22528.jpg
# ./handwriting-recognition/test_v2/test/TEST_15384.jpg
# ./handwriting-recognition/test_v2/test/TEST_35054.jpg
# ./handwriting-recognition/test_v2/test/TEST_25247.jpg
# ./handwriting-recognition/test_v2/test/TEST_33425.jpg
# ./handwriting-recognition/test_v2/test/TEST_24159.jpg
# ./handwriting-recognition/test_v2/test/TEST_23636.jpg
# ./handwriting-recognition/test_v2/test/TEST_23150.jpg
# ./handwriting-recognition/test_v2/test/TEST_33343.jpg
# ./handwriting-recognition/test_v2/test/TEST_13093.jpg
# ./handwriting-recognition/test_v2/test/TEST_14924.jpg
# ./handwriting-recognition/test_v2/test/TEST_25521.jpg
# ./handwriting-recognition/test_v2/test/TEST_2976.jpg
# ./handwriting-recognition/test_v2/test/TEST_35732.jpg
# ./handwriting-recognition/test_v2/test/TEST_39108.jpg
# ./handwriting-recognition/test_v2/test/TEST_30892.jpg
# ./handwriting-recognition/test_v2/test/TEST_21747.jpg
# ./handwriting-recognition/test_v2/test/TEST_26028.jpg
# ./handwriting-recognition/test_v2/test/TEST_11684.jpg
# ./handwriting-recognition/test_v2/test/TEST_31554.jpg
# ./handwriting-recognition/test_v2/test/TEST_9823.jpg
# ./handwriting-recognition/test_v2/test/TEST_27336.jpg
# ./handwriting-recognition/test_v2/test/TEST_28005.jpg
# ./handwriting-recognition/test_v2/test/TEST_37125.jpg
# ./handwriting-recognition/test_v2/test/TEST_20459.jpg
# ./handwriting-recognition/test_v2/test/TEST_38216.jpg
# ./handwriting-recognition/test_v2/test/TEST_34404.jpg
# ./handwriting-recognition/test_v2/test/TEST_23178.jpg
# ./handwriting-recognition/test_v2/test/TEST_24617.jpg
# ./handwriting-recognition/test_v2/test/TEST_2786.jpg
# ./handwriting-recognition/test_v2/test/TEST_25509.jpg
# ./handwriting-recognition/test_v2/test/TEST_32075.jpg
# ./handwriting-recognition/test_v2/test/TEST_3498.jpg
# ./handwriting-recognition/test_v2/test/TEST_22266.jpg
# ./handwriting-recognition/test_v2/test/TEST_39120.jpg
# ./handwriting-recognition/test_v2/test/TEST_36213.jpg
# ./handwriting-recognition/test_v2/test/TEST_29333.jpg
# ./handwriting-recognition/test_v2/test/TEST_0191.jpg
# ./handwriting-recognition/test_v2/test/TEST_40385.jpg
# ./handwriting-recognition/test_v2/test/TEST_26000.jpg
# ./handwriting-recognition/test_v2/test/TEST_30662.jpg
# ./handwriting-recognition/test_v2/test/TEST_7826.jpg
# ./handwriting-recognition/test_v2/test/TEST_20471.jpg
# ./handwriting-recognition/test_v2/test/TEST_11874.jpg
# ./handwriting-recognition/test_v2/test/TEST_38558.jpg
# ./handwriting-recognition/test_v2/test/TEST_20317.jpg
# ./handwriting-recognition/test_v2/test/TEST_6286.jpg
# ./handwriting-recognition/test_v2/test/TEST_18688.jpg
# ./handwriting-recognition/test_v2/test/TEST_30104.jpg
# ./handwriting-recognition/test_v2/test/TEST_27478.jpg
# ./handwriting-recognition/test_v2/test/TEST_29455.jpg
# ./handwriting-recognition/test_v2/test/TEST_26766.jpg
# ./handwriting-recognition/test_v2/test/TEST_18850.jpg
# ./handwriting-recognition/test_v2/test/TEST_21009.jpg
# ./handwriting-recognition/test_v2/test/TEST_28993.jpg
# ./handwriting-recognition/test_v2/test/TEST_39646.jpg
# ./handwriting-recognition/test_v2/test/TEST_36575.jpg
# ./handwriting-recognition/test_v2/test/TEST_19596.jpg
# ./handwriting-recognition/test_v2/test/TEST_7198.jpg
# ./handwriting-recognition/test_v2/test/TEST_13905.jpg
# ./handwriting-recognition/test_v2/test/TEST_4491.jpg
# ./handwriting-recognition/test_v2/test/TEST_22500.jpg
# ./handwriting-recognition/test_v2/test/TEST_5957.jpg
# ./handwriting-recognition/test_v2/test/TEST_32713.jpg
# ./handwriting-recognition/test_v2/test/TEST_24171.jpg
# ./handwriting-recognition/test_v2/test/TEST_34362.jpg
# ./handwriting-recognition/test_v2/test/TEST_35068.jpg
# ./handwriting-recognition/test_v2/test/TEST_4485.jpg
# ./handwriting-recognition/test_v2/test/TEST_13911.jpg
# ./handwriting-recognition/test_v2/test/TEST_22514.jpg
# ./handwriting-recognition/test_v2/test/TEST_5943.jpg
# ./handwriting-recognition/test_v2/test/TEST_32707.jpg
# ./handwriting-recognition/test_v2/test/TEST_24165.jpg
# ./handwriting-recognition/test_v2/test/TEST_33419.jpg
# ./handwriting-recognition/test_v2/test/TEST_34376.jpg
# ./handwriting-recognition/test_v2/test/TEST_20303.jpg
# ./handwriting-recognition/test_v2/test/TEST_6292.jpg
# ./handwriting-recognition/test_v2/test/TEST_16869.jpg
# ./handwriting-recognition/test_v2/test/TEST_30110.jpg
# ./handwriting-recognition/test_v2/test/TEST_29441.jpg
# ./handwriting-recognition/test_v2/test/TEST_18844.jpg
# ./handwriting-recognition/test_v2/test/TEST_26772.jpg
# ./handwriting-recognition/test_v2/test/TEST_39652.jpg
# ./handwriting-recognition/test_v2/test/TEST_28987.jpg
# ./handwriting-recognition/test_v2/test/TEST_19582.jpg
# ./handwriting-recognition/test_v2/test/TEST_36561.jpg
# ./handwriting-recognition/test_v2/test/TEST_39134.jpg
# ./handwriting-recognition/test_v2/test/TEST_36207.jpg
# ./handwriting-recognition/test_v2/test/TEST_40391.jpg
# ./handwriting-recognition/test_v2/test/TEST_31568.jpg
# ./handwriting-recognition/test_v2/test/TEST_0185.jpg
# ./handwriting-recognition/test_v2/test/TEST_29327.jpg
# ./handwriting-recognition/test_v2/test/TEST_26014.jpg
# ./handwriting-recognition/test_v2/test/TEST_28039.jpg
# ./handwriting-recognition/test_v2/test/TEST_30676.jpg
# ./handwriting-recognition/test_v2/test/TEST_7832.jpg
# ./handwriting-recognition/test_v2/test/TEST_20465.jpg
# ./handwriting-recognition/test_v2/test/TEST_37119.jpg
# ./handwriting-recognition/test_v2/test/TEST_11860.jpg
# ./handwriting-recognition/test_v2/test/TEST_34410.jpg
# ./handwriting-recognition/test_v2/test/TEST_24603.jpg
# ./handwriting-recognition/test_v2/test/TEST_2792.jpg
# ./handwriting-recognition/test_v2/test/TEST_14918.jpg
# ./handwriting-recognition/test_v2/test/TEST_32061.jpg
# ./handwriting-recognition/test_v2/test/TEST_22272.jpg
# ./handwriting-recognition/test_v2/test/TEST_3467.jpg
# ./handwriting-recognition/test_v2/test/TEST_22299.jpg
# ./handwriting-recognition/test_v2/test/TEST_15435.jpg
# ./handwriting-recognition/test_v2/test/TEST_24830.jpg
# ./handwriting-recognition/test_v2/test/TEST_4308.jpg
# ./handwriting-recognition/test_v2/test/TEST_23187.jpg
# ./handwriting-recognition/test_v2/test/TEST_5016.jpg
# ./handwriting-recognition/test_v2/test/TEST_33394.jpg
# ./handwriting-recognition/test_v2/test/TEST_2779.jpg
# ./handwriting-recognition/test_v2/test/TEST_13044.jpg
# ./handwriting-recognition/test_v2/test/TEST_1270.jpg
# ./handwriting-recognition/test_v2/test/TEST_41064.jpg
# ./handwriting-recognition/test_v2/test/TEST_21948.jpg
# ./handwriting-recognition/test_v2/test/TEST_18111.jpg
# ./handwriting-recognition/test_v2/test/TEST_17222.jpg
# ./handwriting-recognition/test_v2/test/TEST_7601.jpg
# ./handwriting-recognition/test_v2/test/TEST_8532.jpg
# ./handwriting-recognition/test_v2/test/TEST_21790.jpg
# ./handwriting-recognition/test_v2/test/TEST_30845.jpg
# ./handwriting-recognition/test_v2/test/TEST_11653.jpg
# ./handwriting-recognition/test_v2/test/TEST_31583.jpg
# ./handwriting-recognition/test_v2/test/TEST_26799.jpg
# ./handwriting-recognition/test_v2/test/TEST_11135.jpg
# ./handwriting-recognition/test_v2/test/TEST_0608.jpg
# ./handwriting-recognition/test_v2/test/TEST_7167.jpg
# ./handwriting-recognition/test_v2/test/TEST_19569.jpg
# ./handwriting-recognition/test_v2/test/TEST_8254.jpg
# ./handwriting-recognition/test_v2/test/TEST_37694.jpg
# ./handwriting-recognition/test_v2/test/TEST_18677.jpg
# ./handwriting-recognition/test_v2/test/TEST_6279.jpg
# ./handwriting-recognition/test_v2/test/TEST_26941.jpg
# ./handwriting-recognition/test_v2/test/TEST_17544.jpg
# ./handwriting-recognition/test_v2/test/TEST_27487.jpg
# ./handwriting-recognition/test_v2/test/TEST_16882.jpg
# ./handwriting-recognition/test_v2/test/TEST_39861.jpg
# ./handwriting-recognition/test_v2/test/TEST_1516.jpg
# ./handwriting-recognition/test_v2/test/TEST_13722.jpg
# ./handwriting-recognition/test_v2/test/TEST_32934.jpg
# ./handwriting-recognition/test_v2/test/TEST_5770.jpg
# ./handwriting-recognition/test_v2/test/TEST_15353.jpg
# ./handwriting-recognition/test_v2/test/TEST_35083.jpg
# ./handwriting-recognition/test_v2/test/TEST_23839.jpg
# ./handwriting-recognition/test_v2/test/TEST_3301.jpg
# ./handwriting-recognition/test_v2/test/TEST_25290.jpg
# ./handwriting-recognition/test_v2/test/TEST_13736.jpg
# ./handwriting-recognition/test_v2/test/TEST_32920.jpg
# ./handwriting-recognition/test_v2/test/TEST_14059.jpg
# ./handwriting-recognition/test_v2/test/TEST_34389.jpg
# ./handwriting-recognition/test_v2/test/TEST_5764.jpg
# ./handwriting-recognition/test_v2/test/TEST_15347.jpg
# ./handwriting-recognition/test_v2/test/TEST_35097.jpg
# ./handwriting-recognition/test_v2/test/TEST_3315.jpg
# ./handwriting-recognition/test_v2/test/TEST_25284.jpg
# ./handwriting-recognition/test_v2/test/TEST_12428.jpg
# ./handwriting-recognition/test_v2/test/TEST_11121.jpg
# ./handwriting-recognition/test_v2/test/TEST_37858.jpg
# ./handwriting-recognition/test_v2/test/TEST_40408.jpg
# ./handwriting-recognition/test_v2/test/TEST_7173.jpg
# ./handwriting-recognition/test_v2/test/TEST_8240.jpg
# ./handwriting-recognition/test_v2/test/TEST_28978.jpg
# ./handwriting-recognition/test_v2/test/TEST_26955.jpg
# ./handwriting-recognition/test_v2/test/TEST_18663.jpg
# ./handwriting-recognition/test_v2/test/TEST_37680.jpg
# ./handwriting-recognition/test_v2/test/TEST_17550.jpg
# ./handwriting-recognition/test_v2/test/TEST_27493.jpg
# ./handwriting-recognition/test_v2/test/TEST_1502.jpg
# ./handwriting-recognition/test_v2/test/TEST_39875.jpg
# ./handwriting-recognition/test_v2/test/TEST_16896.jpg
# ./handwriting-recognition/test_v2/test/TEST_10559.jpg
# ./handwriting-recognition/test_v2/test/TEST_30689.jpg
# ./handwriting-recognition/test_v2/test/TEST_41070.jpg
# ./handwriting-recognition/test_v2/test/TEST_1264.jpg
# ./handwriting-recognition/test_v2/test/TEST_18105.jpg
# ./handwriting-recognition/test_v2/test/TEST_17236.jpg
# ./handwriting-recognition/test_v2/test/TEST_9638.jpg
# ./handwriting-recognition/test_v2/test/TEST_7615.jpg
# ./handwriting-recognition/test_v2/test/TEST_30851.jpg
# ./handwriting-recognition/test_v2/test/TEST_21784.jpg
# ./handwriting-recognition/test_v2/test/TEST_8526.jpg
# ./handwriting-recognition/test_v2/test/TEST_16128.jpg
# ./handwriting-recognition/test_v2/test/TEST_11647.jpg
# ./handwriting-recognition/test_v2/test/TEST_31597.jpg
# ./handwriting-recognition/test_v2/test/TEST_3473.jpg
# ./handwriting-recognition/test_v2/test/TEST_15421.jpg
# ./handwriting-recognition/test_v2/test/TEST_24824.jpg
# ./handwriting-recognition/test_v2/test/TEST_23193.jpg
# ./handwriting-recognition/test_v2/test/TEST_5002.jpg
# ./handwriting-recognition/test_v2/test/TEST_33380.jpg
# ./handwriting-recognition/test_v2/test/TEST_13050.jpg
# ./handwriting-recognition/test_v2/test/TEST_35929.jpg
# ./handwriting-recognition/test_v2/test/TEST_41058.jpg
# ./handwriting-recognition/test_v2/test/TEST_21974.jpg
# ./handwriting-recognition/test_v2/test/TEST_10571.jpg
# ./handwriting-recognition/test_v2/test/TEST_9610.jpg
# ./handwriting-recognition/test_v2/test/TEST_6523.jpg
# ./handwriting-recognition/test_v2/test/TEST_16100.jpg
# ./handwriting-recognition/test_v2/test/TEST_30879.jpg
# ./handwriting-recognition/test_v2/test/TEST_19233.jpg
# ./handwriting-recognition/test_v2/test/TEST_40346.jpg
# ./handwriting-recognition/test_v2/test/TEST_0152.jpg
# ./handwriting-recognition/test_v2/test/TEST_12366.jpg
# ./handwriting-recognition/test_v2/test/TEST_4334.jpg
# ./handwriting-recognition/test_v2/test/TEST_15409.jpg
# ./handwriting-recognition/test_v2/test/TEST_14717.jpg
# ./handwriting-recognition/test_v2/test/TEST_35901.jpg
# ./handwriting-recognition/test_v2/test/TEST_13078.jpg
# ./handwriting-recognition/test_v2/test/TEST_2745.jpg
# ./handwriting-recognition/test_v2/test/TEST_2023.jpg
# ./handwriting-recognition/test_v2/test/TEST_14071.jpg
# ./handwriting-recognition/test_v2/test/TEST_32908.jpg
# ./handwriting-recognition/test_v2/test/TEST_4452.jpg
# ./handwriting-recognition/test_v2/test/TEST_12400.jpg
# ./handwriting-recognition/test_v2/test/TEST_5994.jpg
# ./handwriting-recognition/test_v2/test/TEST_23805.jpg
# ./handwriting-recognition/test_v2/test/TEST_40420.jpg
# ./handwriting-recognition/test_v2/test/TEST_0634.jpg
# ./handwriting-recognition/test_v2/test/TEST_29496.jpg
# ./handwriting-recognition/test_v2/test/TEST_18893.jpg
# ./handwriting-recognition/test_v2/test/TEST_37870.jpg
# ./handwriting-recognition/test_v2/test/TEST_11109.jpg
# ./handwriting-recognition/test_v2/test/TEST_28950.jpg
# ./handwriting-recognition/test_v2/test/TEST_39685.jpg
# ./handwriting-recognition/test_v2/test/TEST_16666.jpg
# ./handwriting-recognition/test_v2/test/TEST_8268.jpg
# ./handwriting-recognition/test_v2/test/TEST_19555.jpg
# ./handwriting-recognition/test_v2/test/TEST_9176.jpg
# ./handwriting-recognition/test_v2/test/TEST_17578.jpg
# ./handwriting-recognition/test_v2/test/TEST_6245.jpg
# ./handwriting-recognition/test_v2/test/TEST_28788.jpg
# ./handwriting-recognition/test_v2/test/TEST_10217.jpg
# ./handwriting-recognition/test_v2/test/TEST_29482.jpg
# ./handwriting-recognition/test_v2/test/TEST_0620.jpg
# ./handwriting-recognition/test_v2/test/TEST_40434.jpg
# ./handwriting-recognition/test_v2/test/TEST_37864.jpg
# ./handwriting-recognition/test_v2/test/TEST_18887.jpg
# ./handwriting-recognition/test_v2/test/TEST_16672.jpg
# ./handwriting-recognition/test_v2/test/TEST_39691.jpg
# ./handwriting-recognition/test_v2/test/TEST_28944.jpg
# ./handwriting-recognition/test_v2/test/TEST_19541.jpg
# ./handwriting-recognition/test_v2/test/TEST_9162.jpg
# ./handwriting-recognition/test_v2/test/TEST_26969.jpg
# ./handwriting-recognition/test_v2/test/TEST_6251.jpg
# ./handwriting-recognition/test_v2/test/TEST_39849.jpg
# ./handwriting-recognition/test_v2/test/TEST_10203.jpg
# ./handwriting-recognition/test_v2/test/TEST_2037.jpg
# ./handwriting-recognition/test_v2/test/TEST_5758.jpg
# ./handwriting-recognition/test_v2/test/TEST_14065.jpg
# ./handwriting-recognition/test_v2/test/TEST_4446.jpg
# ./handwriting-recognition/test_v2/test/TEST_5980.jpg
# ./handwriting-recognition/test_v2/test/TEST_12414.jpg
# ./handwriting-recognition/test_v2/test/TEST_3329.jpg
# ./handwriting-recognition/test_v2/test/TEST_23811.jpg
# ./handwriting-recognition/test_v2/test/TEST_12372.jpg
# ./handwriting-recognition/test_v2/test/TEST_4320.jpg
# ./handwriting-recognition/test_v2/test/TEST_24818.jpg
# ./handwriting-recognition/test_v2/test/TEST_2989.jpg
# ./handwriting-recognition/test_v2/test/TEST_14703.jpg
# ./handwriting-recognition/test_v2/test/TEST_35915.jpg
# ./handwriting-recognition/test_v2/test/TEST_2751.jpg
# ./handwriting-recognition/test_v2/test/TEST_21960.jpg
# ./handwriting-recognition/test_v2/test/TEST_1258.jpg
# ./handwriting-recognition/test_v2/test/TEST_10565.jpg
# ./handwriting-recognition/test_v2/test/TEST_9604.jpg
# ./handwriting-recognition/test_v2/test/TEST_6537.jpg
# ./handwriting-recognition/test_v2/test/TEST_18139.jpg
# ./handwriting-recognition/test_v2/test/TEST_16114.jpg
# ./handwriting-recognition/test_v2/test/TEST_19227.jpg
# ./handwriting-recognition/test_v2/test/TEST_7629.jpg
# ./handwriting-recognition/test_v2/test/TEST_0146.jpg
# ./handwriting-recognition/test_v2/test/TEST_40352.jpg
# ./handwriting-recognition/test_v2/test/TEST_8095.jpg
# ./handwriting-recognition/test_v2/test/TEST_39478.jpg
# ./handwriting-recognition/test_v2/test/TEST_21237.jpg
# ./handwriting-recognition/test_v2/test/TEST_31024.jpg
# ./handwriting-recognition/test_v2/test/TEST_26558.jpg
# ./handwriting-recognition/test_v2/test/TEST_28575.jpg
# ./handwriting-recognition/test_v2/test/TEST_27646.jpg
# ./handwriting-recognition/test_v2/test/TEST_19970.jpg
# ./handwriting-recognition/test_v2/test/TEST_36993.jpg
# ./handwriting-recognition/test_v2/test/TEST_40805.jpg
# ./handwriting-recognition/test_v2/test/TEST_20129.jpg
# ./handwriting-recognition/test_v2/test/TEST_38766.jpg
# ./handwriting-recognition/test_v2/test/TEST_17785.jpg
# ./handwriting-recognition/test_v2/test/TEST_37455.jpg
# ./handwriting-recognition/test_v2/test/TEST_12825.jpg
# ./handwriting-recognition/test_v2/test/TEST_23420.jpg
# ./handwriting-recognition/test_v2/test/TEST_4877.jpg
# ./handwriting-recognition/test_v2/test/TEST_33633.jpg
# ./handwriting-recognition/test_v2/test/TEST_25051.jpg
# ./handwriting-recognition/test_v2/test/TEST_35242.jpg
# ./handwriting-recognition/test_v2/test/TEST_15192.jpg
# ./handwriting-recognition/test_v2/test/TEST_35524.jpg
# ./handwriting-recognition/test_v2/test/TEST_22058.jpg
# ./handwriting-recognition/test_v2/test/TEST_25737.jpg
# ./handwriting-recognition/test_v2/test/TEST_24429.jpg
# ./handwriting-recognition/test_v2/test/TEST_13285.jpg
# ./handwriting-recognition/test_v2/test/TEST_33155.jpg
# ./handwriting-recognition/test_v2/test/TEST_23346.jpg
# ./handwriting-recognition/test_v2/test/TEST_38000.jpg
# ./handwriting-recognition/test_v2/test/TEST_37333.jpg
# ./handwriting-recognition/test_v2/test/TEST_28213.jpg
# ./handwriting-recognition/test_v2/test/TEST_27120.jpg
# ./handwriting-recognition/test_v2/test/TEST_31742.jpg
# ./handwriting-recognition/test_v2/test/TEST_20897.jpg
# ./handwriting-recognition/test_v2/test/TEST_6906.jpg
# ./handwriting-recognition/test_v2/test/TEST_11492.jpg
# ./handwriting-recognition/test_v2/test/TEST_21551.jpg
# ./handwriting-recognition/test_v2/test/TEST_10954.jpg
# ./handwriting-recognition/test_v2/test/TEST_38014.jpg
# ./handwriting-recognition/test_v2/test/TEST_37327.jpg
# ./handwriting-recognition/test_v2/test/TEST_30448.jpg
# ./handwriting-recognition/test_v2/test/TEST_28207.jpg
# ./handwriting-recognition/test_v2/test/TEST_27134.jpg
# ./handwriting-recognition/test_v2/test/TEST_10798.jpg
# ./handwriting-recognition/test_v2/test/TEST_29119.jpg
# ./handwriting-recognition/test_v2/test/TEST_20883.jpg
# ./handwriting-recognition/test_v2/test/TEST_31756.jpg
# ./handwriting-recognition/test_v2/test/TEST_11486.jpg
# ./handwriting-recognition/test_v2/test/TEST_6912.jpg
# ./handwriting-recognition/test_v2/test/TEST_21545.jpg
# ./handwriting-recognition/test_v2/test/TEST_36039.jpg
# ./handwriting-recognition/test_v2/test/TEST_10940.jpg
# ./handwriting-recognition/test_v2/test/TEST_35530.jpg
# ./handwriting-recognition/test_v2/test/TEST_25723.jpg
# ./handwriting-recognition/test_v2/test/TEST_13291.jpg
# ./handwriting-recognition/test_v2/test/TEST_15838.jpg
# ./handwriting-recognition/test_v2/test/TEST_33141.jpg
# ./handwriting-recognition/test_v2/test/TEST_23352.jpg
# ./handwriting-recognition/test_v2/test/TEST_34148.jpg
# ./handwriting-recognition/test_v2/test/TEST_12831.jpg
# ./handwriting-recognition/test_v2/test/TEST_23434.jpg
# ./handwriting-recognition/test_v2/test/TEST_14298.jpg
# ./handwriting-recognition/test_v2/test/TEST_4863.jpg
# ./handwriting-recognition/test_v2/test/TEST_33627.jpg
# ./handwriting-recognition/test_v2/test/TEST_25045.jpg
# ./handwriting-recognition/test_v2/test/TEST_32539.jpg
# ./handwriting-recognition/test_v2/test/TEST_35256.jpg
# ./handwriting-recognition/test_v2/test/TEST_15186.jpg
# ./handwriting-recognition/test_v2/test/TEST_21223.jpg
# ./handwriting-recognition/test_v2/test/TEST_8081.jpg
# ./handwriting-recognition/test_v2/test/TEST_17949.jpg
# ./handwriting-recognition/test_v2/test/TEST_31030.jpg
# ./handwriting-recognition/test_v2/test/TEST_28561.jpg
# ./handwriting-recognition/test_v2/test/TEST_36987.jpg
# ./handwriting-recognition/test_v2/test/TEST_19964.jpg
# ./handwriting-recognition/test_v2/test/TEST_27652.jpg
# ./handwriting-recognition/test_v2/test/TEST_17791.jpg
# ./handwriting-recognition/test_v2/test/TEST_38772.jpg
# ./handwriting-recognition/test_v2/test/TEST_40811.jpg
# ./handwriting-recognition/test_v2/test/TEST_37441.jpg
# ./handwriting-recognition/test_v2/test/TEST_12819.jpg
# ./handwriting-recognition/test_v2/test/TEST_34160.jpg
# ./handwriting-recognition/test_v2/test/TEST_24373.jpg
# ./handwriting-recognition/test_v2/test/TEST_32511.jpg
# ./handwriting-recognition/test_v2/test/TEST_22702.jpg
# ./handwriting-recognition/test_v2/test/TEST_4693.jpg
# ./handwriting-recognition/test_v2/test/TEST_36777.jpg
# ./handwriting-recognition/test_v2/test/TEST_19794.jpg
# ./handwriting-recognition/test_v2/test/TEST_39444.jpg
# ./handwriting-recognition/test_v2/test/TEST_1933.jpg
# ./handwriting-recognition/test_v2/test/TEST_26564.jpg
# ./handwriting-recognition/test_v2/test/TEST_31018.jpg
# ./handwriting-recognition/test_v2/test/TEST_17961.jpg
# ./handwriting-recognition/test_v2/test/TEST_38982.jpg
# ./handwriting-recognition/test_v2/test/TEST_29657.jpg
# ./handwriting-recognition/test_v2/test/TEST_28549.jpg
# ./handwriting-recognition/test_v2/test/TEST_30306.jpg
# ./handwriting-recognition/test_v2/test/TEST_6084.jpg
# ./handwriting-recognition/test_v2/test/TEST_37469.jpg
# ./handwriting-recognition/test_v2/test/TEST_40839.jpg
# ./handwriting-recognition/test_v2/test/TEST_20115.jpg
# ./handwriting-recognition/test_v2/test/TEST_20673.jpg
# ./handwriting-recognition/test_v2/test/TEST_8917.jpg
# ./handwriting-recognition/test_v2/test/TEST_41299.jpg
# ./handwriting-recognition/test_v2/test/TEST_30460.jpg
# ./handwriting-recognition/test_v2/test/TEST_26202.jpg
# ./handwriting-recognition/test_v2/test/TEST_0393.jpg
# ./handwriting-recognition/test_v2/test/TEST_40187.jpg
# ./handwriting-recognition/test_v2/test/TEST_29131.jpg
# ./handwriting-recognition/test_v2/test/TEST_10968.jpg
# ./handwriting-recognition/test_v2/test/TEST_36011.jpg
# ./handwriting-recognition/test_v2/test/TEST_39322.jpg
# ./handwriting-recognition/test_v2/test/TEST_22064.jpg
# ./handwriting-recognition/test_v2/test/TEST_35518.jpg
# ./handwriting-recognition/test_v2/test/TEST_32277.jpg
# ./handwriting-recognition/test_v2/test/TEST_2584.jpg
# ./handwriting-recognition/test_v2/test/TEST_33169.jpg
# ./handwriting-recognition/test_v2/test/TEST_15810.jpg
# ./handwriting-recognition/test_v2/test/TEST_24415.jpg
# ./handwriting-recognition/test_v2/test/TEST_3842.jpg
# ./handwriting-recognition/test_v2/test/TEST_34606.jpg
# ./handwriting-recognition/test_v2/test/TEST_22070.jpg
# ./handwriting-recognition/test_v2/test/TEST_32263.jpg
# ./handwriting-recognition/test_v2/test/TEST_15804.jpg
# ./handwriting-recognition/test_v2/test/TEST_2590.jpg
# ./handwriting-recognition/test_v2/test/TEST_24401.jpg
# ./handwriting-recognition/test_v2/test/TEST_3856.jpg
# ./handwriting-recognition/test_v2/test/TEST_34612.jpg
# ./handwriting-recognition/test_v2/test/TEST_38028.jpg
# ./handwriting-recognition/test_v2/test/TEST_20667.jpg
# ./handwriting-recognition/test_v2/test/TEST_27108.jpg
# ./handwriting-recognition/test_v2/test/TEST_1099.jpg
# ./handwriting-recognition/test_v2/test/TEST_30474.jpg
# ./handwriting-recognition/test_v2/test/TEST_8903.jpg
# ./handwriting-recognition/test_v2/test/TEST_26216.jpg
# ./handwriting-recognition/test_v2/test/TEST_29125.jpg
# ./handwriting-recognition/test_v2/test/TEST_40193.jpg
# ./handwriting-recognition/test_v2/test/TEST_0387.jpg
# ./handwriting-recognition/test_v2/test/TEST_36005.jpg
# ./handwriting-recognition/test_v2/test/TEST_21579.jpg
# ./handwriting-recognition/test_v2/test/TEST_39336.jpg
# ./handwriting-recognition/test_v2/test/TEST_19780.jpg
# ./handwriting-recognition/test_v2/test/TEST_36763.jpg
# ./handwriting-recognition/test_v2/test/TEST_1927.jpg
# ./handwriting-recognition/test_v2/test/TEST_39450.jpg
# ./handwriting-recognition/test_v2/test/TEST_26570.jpg
# ./handwriting-recognition/test_v2/test/TEST_29643.jpg
# ./handwriting-recognition/test_v2/test/TEST_38996.jpg
# ./handwriting-recognition/test_v2/test/TEST_17975.jpg
# ./handwriting-recognition/test_v2/test/TEST_19958.jpg
# ./handwriting-recognition/test_v2/test/TEST_30312.jpg
# ./handwriting-recognition/test_v2/test/TEST_6090.jpg
# ./handwriting-recognition/test_v2/test/TEST_20101.jpg
# ./handwriting-recognition/test_v2/test/TEST_23408.jpg
# ./handwriting-recognition/test_v2/test/TEST_5599.jpg
# ./handwriting-recognition/test_v2/test/TEST_34174.jpg
# ./handwriting-recognition/test_v2/test/TEST_24367.jpg
# ./handwriting-recognition/test_v2/test/TEST_32505.jpg
# ./handwriting-recognition/test_v2/test/TEST_25079.jpg
# ./handwriting-recognition/test_v2/test/TEST_22716.jpg
# ./handwriting-recognition/test_v2/test/TEST_4687.jpg
# ./handwriting-recognition/test_v2/test/TEST_25092.jpg
# ./handwriting-recognition/test_v2/test/TEST_3103.jpg
# ./handwriting-recognition/test_v2/test/TEST_35281.jpg
# ./handwriting-recognition/test_v2/test/TEST_15151.jpg
# ./handwriting-recognition/test_v2/test/TEST_33828.jpg
# ./handwriting-recognition/test_v2/test/TEST_5572.jpg
# ./handwriting-recognition/test_v2/test/TEST_13520.jpg
# ./handwriting-recognition/test_v2/test/TEST_22925.jpg
# ./handwriting-recognition/test_v2/test/TEST_1714.jpg
# ./handwriting-recognition/test_v2/test/TEST_27685.jpg
# ./handwriting-recognition/test_v2/test/TEST_36950.jpg
# ./handwriting-recognition/test_v2/test/TEST_10029.jpg
# ./handwriting-recognition/test_v2/test/TEST_29870.jpg
# ./handwriting-recognition/test_v2/test/TEST_9348.jpg
# ./handwriting-recognition/test_v2/test/TEST_17746.jpg
# ./handwriting-recognition/test_v2/test/TEST_37496.jpg
# ./handwriting-recognition/test_v2/test/TEST_18475.jpg
# ./handwriting-recognition/test_v2/test/TEST_16458.jpg
# ./handwriting-recognition/test_v2/test/TEST_8056.jpg
# ./handwriting-recognition/test_v2/test/TEST_7365.jpg
# ./handwriting-recognition/test_v2/test/TEST_36788.jpg
# ./handwriting-recognition/test_v2/test/TEST_11337.jpg
# ./handwriting-recognition/test_v2/test/TEST_31781.jpg
# ./handwriting-recognition/test_v2/test/TEST_40178.jpg
# ./handwriting-recognition/test_v2/test/TEST_20854.jpg
# ./handwriting-recognition/test_v2/test/TEST_11451.jpg
# ./handwriting-recognition/test_v2/test/TEST_21592.jpg
# ./handwriting-recognition/test_v2/test/TEST_8730.jpg
# ./handwriting-recognition/test_v2/test/TEST_7403.jpg
# ./handwriting-recognition/test_v2/test/TEST_10997.jpg
# ./handwriting-recognition/test_v2/test/TEST_17020.jpg
# ./handwriting-recognition/test_v2/test/TEST_31959.jpg
# ./handwriting-recognition/test_v2/test/TEST_18313.jpg
# ./handwriting-recognition/test_v2/test/TEST_1072.jpg
# ./handwriting-recognition/test_v2/test/TEST_41266.jpg
# ./handwriting-recognition/test_v2/test/TEST_13246.jpg
# ./handwriting-recognition/test_v2/test/TEST_33196.jpg
# ./handwriting-recognition/test_v2/test/TEST_5214.jpg
# ./handwriting-recognition/test_v2/test/TEST_23385.jpg
# ./handwriting-recognition/test_v2/test/TEST_14529.jpg
# ./handwriting-recognition/test_v2/test/TEST_15637.jpg
# ./handwriting-recognition/test_v2/test/TEST_34821.jpg
# ./handwriting-recognition/test_v2/test/TEST_12158.jpg
# ./handwriting-recognition/test_v2/test/TEST_3665.jpg
# ./handwriting-recognition/test_v2/test/TEST_32288.jpg
# ./handwriting-recognition/test_v2/test/TEST_13252.jpg
# ./handwriting-recognition/test_v2/test/TEST_33182.jpg
# ./handwriting-recognition/test_v2/test/TEST_5200.jpg
# ./handwriting-recognition/test_v2/test/TEST_25938.jpg
# ./handwriting-recognition/test_v2/test/TEST_23391.jpg
# ./handwriting-recognition/test_v2/test/TEST_15623.jpg
# ./handwriting-recognition/test_v2/test/TEST_34835.jpg
# ./handwriting-recognition/test_v2/test/TEST_3671.jpg
# ./handwriting-recognition/test_v2/test/TEST_20840.jpg
# ./handwriting-recognition/test_v2/test/TEST_0378.jpg
# ./handwriting-recognition/test_v2/test/TEST_31795.jpg
# ./handwriting-recognition/test_v2/test/TEST_11445.jpg
# ./handwriting-recognition/test_v2/test/TEST_8724.jpg
# ./handwriting-recognition/test_v2/test/TEST_21586.jpg
# ./handwriting-recognition/test_v2/test/TEST_10983.jpg
# ./handwriting-recognition/test_v2/test/TEST_19019.jpg
# ./handwriting-recognition/test_v2/test/TEST_7417.jpg
# ./handwriting-recognition/test_v2/test/TEST_20698.jpg
# ./handwriting-recognition/test_v2/test/TEST_17034.jpg
# ./handwriting-recognition/test_v2/test/TEST_6709.jpg
# ./handwriting-recognition/test_v2/test/TEST_18307.jpg
# ./handwriting-recognition/test_v2/test/TEST_41272.jpg
# ./handwriting-recognition/test_v2/test/TEST_1066.jpg
# ./handwriting-recognition/test_v2/test/TEST_1700.jpg
# ./handwriting-recognition/test_v2/test/TEST_36944.jpg
# ./handwriting-recognition/test_v2/test/TEST_27691.jpg
# ./handwriting-recognition/test_v2/test/TEST_17752.jpg
# ./handwriting-recognition/test_v2/test/TEST_29864.jpg
# ./handwriting-recognition/test_v2/test/TEST_18461.jpg
# ./handwriting-recognition/test_v2/test/TEST_37482.jpg
# ./handwriting-recognition/test_v2/test/TEST_8042.jpg
# ./handwriting-recognition/test_v2/test/TEST_27849.jpg
# ./handwriting-recognition/test_v2/test/TEST_7371.jpg
# ./handwriting-recognition/test_v2/test/TEST_38969.jpg
# ./handwriting-recognition/test_v2/test/TEST_11323.jpg
# ./handwriting-recognition/test_v2/test/TEST_25086.jpg
# ./handwriting-recognition/test_v2/test/TEST_3117.jpg
# ./handwriting-recognition/test_v2/test/TEST_4678.jpg
# ./handwriting-recognition/test_v2/test/TEST_35295.jpg
# ./handwriting-recognition/test_v2/test/TEST_15145.jpg
# ./handwriting-recognition/test_v2/test/TEST_5566.jpg
# ./handwriting-recognition/test_v2/test/TEST_24398.jpg
# ./handwriting-recognition/test_v2/test/TEST_13534.jpg
# ./handwriting-recognition/test_v2/test/TEST_2209.jpg
# ./handwriting-recognition/test_v2/test/TEST_22931.jpg
# ./handwriting-recognition/test_v2/test/TEST_10015.jpg
# ./handwriting-recognition/test_v2/test/TEST_1728.jpg
# ./handwriting-recognition/test_v2/test/TEST_18449.jpg
# ./handwriting-recognition/test_v2/test/TEST_6047.jpg
# ./handwriting-recognition/test_v2/test/TEST_9374.jpg
# ./handwriting-recognition/test_v2/test/TEST_38799.jpg
# ./handwriting-recognition/test_v2/test/TEST_7359.jpg
# ./handwriting-recognition/test_v2/test/TEST_19757.jpg
# ./handwriting-recognition/test_v2/test/TEST_27861.jpg
# ./handwriting-recognition/test_v2/test/TEST_39487.jpg
# ./handwriting-recognition/test_v2/test/TEST_16464.jpg
# ./handwriting-recognition/test_v2/test/TEST_38941.jpg
# ./handwriting-recognition/test_v2/test/TEST_29694.jpg
# ./handwriting-recognition/test_v2/test/TEST_40622.jpg
# ./handwriting-recognition/test_v2/test/TEST_0436.jpg
# ./handwriting-recognition/test_v2/test/TEST_12602.jpg
# ./handwriting-recognition/test_v2/test/TEST_33814.jpg
# ./handwriting-recognition/test_v2/test/TEST_4650.jpg
# ./handwriting-recognition/test_v2/test/TEST_14273.jpg
# ./handwriting-recognition/test_v2/test/TEST_22919.jpg
# ./handwriting-recognition/test_v2/test/TEST_2221.jpg
# ./handwriting-recognition/test_v2/test/TEST_4888.jpg
# ./handwriting-recognition/test_v2/test/TEST_2547.jpg
# ./handwriting-recognition/test_v2/test/TEST_3881.jpg
# ./handwriting-recognition/test_v2/test/TEST_14515.jpg
# ./handwriting-recognition/test_v2/test/TEST_25910.jpg
# ./handwriting-recognition/test_v2/test/TEST_5228.jpg
# ./handwriting-recognition/test_v2/test/TEST_4136.jpg
# ./handwriting-recognition/test_v2/test/TEST_3659.jpg
# ./handwriting-recognition/test_v2/test/TEST_12164.jpg
# ./handwriting-recognition/test_v2/test/TEST_40144.jpg
# ./handwriting-recognition/test_v2/test/TEST_0350.jpg
# ./handwriting-recognition/test_v2/test/TEST_20868.jpg
# ./handwriting-recognition/test_v2/test/TEST_19031.jpg
# ./handwriting-recognition/test_v2/test/TEST_16302.jpg
# ./handwriting-recognition/test_v2/test/TEST_6721.jpg
# ./handwriting-recognition/test_v2/test/TEST_9412.jpg
# ./handwriting-recognition/test_v2/test/TEST_31965.jpg
# ./handwriting-recognition/test_v2/test/TEST_10773.jpg
# ./handwriting-recognition/test_v2/test/TEST_11479.jpg
# ./handwriting-recognition/test_v2/test/TEST_0344.jpg
# ./handwriting-recognition/test_v2/test/TEST_40150.jpg
# ./handwriting-recognition/test_v2/test/TEST_19025.jpg
# ./handwriting-recognition/test_v2/test/TEST_8718.jpg
# ./handwriting-recognition/test_v2/test/TEST_16316.jpg
# ./handwriting-recognition/test_v2/test/TEST_6735.jpg
# ./handwriting-recognition/test_v2/test/TEST_31971.jpg
# ./handwriting-recognition/test_v2/test/TEST_17008.jpg
# ./handwriting-recognition/test_v2/test/TEST_9406.jpg
# ./handwriting-recognition/test_v2/test/TEST_10767.jpg
# ./handwriting-recognition/test_v2/test/TEST_2553.jpg
# ./handwriting-recognition/test_v2/test/TEST_14501.jpg
# ./handwriting-recognition/test_v2/test/TEST_3895.jpg
# ./handwriting-recognition/test_v2/test/TEST_25904.jpg
# ./handwriting-recognition/test_v2/test/TEST_4122.jpg
# ./handwriting-recognition/test_v2/test/TEST_12170.jpg
# ./handwriting-recognition/test_v2/test/TEST_34809.jpg
# ./handwriting-recognition/test_v2/test/TEST_12616.jpg
# ./handwriting-recognition/test_v2/test/TEST_33800.jpg
# ./handwriting-recognition/test_v2/test/TEST_15179.jpg
# ./handwriting-recognition/test_v2/test/TEST_4644.jpg
# ./handwriting-recognition/test_v2/test/TEST_14267.jpg
# ./handwriting-recognition/test_v2/test/TEST_2235.jpg
# ./handwriting-recognition/test_v2/test/TEST_13508.jpg
# ./handwriting-recognition/test_v2/test/TEST_10001.jpg
# ./handwriting-recognition/test_v2/test/TEST_36978.jpg
# ./handwriting-recognition/test_v2/test/TEST_6053.jpg
# ./handwriting-recognition/test_v2/test/TEST_9360.jpg
# ./handwriting-recognition/test_v2/test/TEST_29858.jpg
# ./handwriting-recognition/test_v2/test/TEST_27875.jpg
# ./handwriting-recognition/test_v2/test/TEST_19743.jpg
# ./handwriting-recognition/test_v2/test/TEST_16470.jpg
# ./handwriting-recognition/test_v2/test/TEST_39493.jpg
# ./handwriting-recognition/test_v2/test/TEST_0422.jpg
# ./handwriting-recognition/test_v2/test/TEST_40636.jpg
# ./handwriting-recognition/test_v2/test/TEST_29680.jpg
# ./handwriting-recognition/test_v2/test/TEST_38955.jpg
# ./handwriting-recognition/test_v2/test/TEST_38612.jpg
# ./handwriting-recognition/test_v2/test/TEST_40971.jpg
# ./handwriting-recognition/test_v2/test/TEST_37521.jpg
# ./handwriting-recognition/test_v2/test/TEST_28401.jpg
# ./handwriting-recognition/test_v2/test/TEST_19804.jpg
# ./handwriting-recognition/test_v2/test/TEST_27732.jpg
# ./handwriting-recognition/test_v2/test/TEST_17829.jpg
# ./handwriting-recognition/test_v2/test/TEST_31150.jpg
# ./handwriting-recognition/test_v2/test/TEST_11280.jpg
# ./handwriting-recognition/test_v2/test/TEST_21343.jpg
# ./handwriting-recognition/test_v2/test/TEST_35336.jpg
# ./handwriting-recognition/test_v2/test/TEST_25125.jpg
# ./handwriting-recognition/test_v2/test/TEST_12789.jpg
# ./handwriting-recognition/test_v2/test/TEST_32459.jpg
# ./handwriting-recognition/test_v2/test/TEST_13497.jpg
# ./handwriting-recognition/test_v2/test/TEST_4903.jpg
# ./handwriting-recognition/test_v2/test/TEST_33747.jpg
# ./handwriting-recognition/test_v2/test/TEST_22892.jpg
# ./handwriting-recognition/test_v2/test/TEST_34028.jpg
# ./handwriting-recognition/test_v2/test/TEST_12951.jpg
# ./handwriting-recognition/test_v2/test/TEST_23554.jpg
# ./handwriting-recognition/test_v2/test/TEST_23232.jpg
# ./handwriting-recognition/test_v2/test/TEST_15958.jpg
# ./handwriting-recognition/test_v2/test/TEST_33021.jpg
# ./handwriting-recognition/test_v2/test/TEST_25643.jpg
# ./handwriting-recognition/test_v2/test/TEST_34996.jpg
# ./handwriting-recognition/test_v2/test/TEST_35450.jpg
# ./handwriting-recognition/test_v2/test/TEST_15780.jpg
# ./handwriting-recognition/test_v2/test/TEST_21425.jpg
# ./handwriting-recognition/test_v2/test/TEST_8687.jpg
# ./handwriting-recognition/test_v2/test/TEST_16289.jpg
# ./handwriting-recognition/test_v2/test/TEST_36159.jpg
# ./handwriting-recognition/test_v2/test/TEST_10820.jpg
# ./handwriting-recognition/test_v2/test/TEST_29079.jpg
# ./handwriting-recognition/test_v2/test/TEST_31636.jpg
# ./handwriting-recognition/test_v2/test/TEST_6872.jpg
# ./handwriting-recognition/test_v2/test/TEST_30528.jpg
# ./handwriting-recognition/test_v2/test/TEST_28367.jpg
# ./handwriting-recognition/test_v2/test/TEST_27054.jpg
# ./handwriting-recognition/test_v2/test/TEST_17197.jpg
# ./handwriting-recognition/test_v2/test/TEST_9599.jpg
# ./handwriting-recognition/test_v2/test/TEST_38174.jpg
# ./handwriting-recognition/test_v2/test/TEST_37247.jpg
# ./handwriting-recognition/test_v2/test/TEST_8693.jpg
# ./handwriting-recognition/test_v2/test/TEST_21431.jpg
# ./handwriting-recognition/test_v2/test/TEST_10834.jpg
# ./handwriting-recognition/test_v2/test/TEST_31622.jpg
# ./handwriting-recognition/test_v2/test/TEST_6866.jpg
# ./handwriting-recognition/test_v2/test/TEST_28373.jpg
# ./handwriting-recognition/test_v2/test/TEST_27040.jpg
# ./handwriting-recognition/test_v2/test/TEST_38160.jpg
# ./handwriting-recognition/test_v2/test/TEST_17183.jpg
# ./handwriting-recognition/test_v2/test/TEST_37253.jpg
# ./handwriting-recognition/test_v2/test/TEST_23226.jpg
# ./handwriting-recognition/test_v2/test/TEST_24549.jpg
# ./handwriting-recognition/test_v2/test/TEST_33035.jpg
# ./handwriting-recognition/test_v2/test/TEST_34982.jpg
# ./handwriting-recognition/test_v2/test/TEST_25657.jpg
# ./handwriting-recognition/test_v2/test/TEST_35444.jpg
# ./handwriting-recognition/test_v2/test/TEST_22138.jpg
# ./handwriting-recognition/test_v2/test/TEST_15794.jpg
# ./handwriting-recognition/test_v2/test/TEST_35322.jpg
# ./handwriting-recognition/test_v2/test/TEST_25131.jpg
# ./handwriting-recognition/test_v2/test/TEST_4917.jpg
# ./handwriting-recognition/test_v2/test/TEST_13483.jpg
# ./handwriting-recognition/test_v2/test/TEST_22886.jpg
# ./handwriting-recognition/test_v2/test/TEST_33753.jpg
# ./handwriting-recognition/test_v2/test/TEST_12945.jpg
# ./handwriting-recognition/test_v2/test/TEST_23540.jpg
# ./handwriting-recognition/test_v2/test/TEST_40965.jpg
# ./handwriting-recognition/test_v2/test/TEST_20049.jpg
# ./handwriting-recognition/test_v2/test/TEST_38606.jpg
# ./handwriting-recognition/test_v2/test/TEST_37535.jpg
# ./handwriting-recognition/test_v2/test/TEST_28415.jpg
# ./handwriting-recognition/test_v2/test/TEST_27726.jpg
# ./handwriting-recognition/test_v2/test/TEST_19810.jpg
# ./handwriting-recognition/test_v2/test/TEST_31144.jpg
# ./handwriting-recognition/test_v2/test/TEST_26438.jpg
# ./handwriting-recognition/test_v2/test/TEST_11294.jpg
# ./handwriting-recognition/test_v2/test/TEST_39518.jpg
# ./handwriting-recognition/test_v2/test/TEST_21357.jpg
# ./handwriting-recognition/test_v2/test/TEST_22676.jpg
# ./handwriting-recognition/test_v2/test/TEST_3088.jpg
# ./handwriting-recognition/test_v2/test/TEST_32465.jpg
# ./handwriting-recognition/test_v2/test/TEST_25119.jpg
# ./handwriting-recognition/test_v2/test/TEST_2396.jpg
# ./handwriting-recognition/test_v2/test/TEST_24207.jpg
# ./handwriting-recognition/test_v2/test/TEST_23568.jpg
# ./handwriting-recognition/test_v2/test/TEST_34014.jpg
# ./handwriting-recognition/test_v2/test/TEST_20061.jpg
# ./handwriting-recognition/test_v2/test/TEST_19838.jpg
# ./handwriting-recognition/test_v2/test/TEST_30272.jpg
# ./handwriting-recognition/test_v2/test/TEST_26410.jpg
# ./handwriting-recognition/test_v2/test/TEST_29723.jpg
# ./handwriting-recognition/test_v2/test/TEST_17815.jpg
# ./handwriting-recognition/test_v2/test/TEST_40795.jpg
# ./handwriting-recognition/test_v2/test/TEST_0581.jpg
# ./handwriting-recognition/test_v2/test/TEST_36603.jpg
# ./handwriting-recognition/test_v2/test/TEST_1847.jpg
# ./handwriting-recognition/test_v2/test/TEST_39530.jpg
# ./handwriting-recognition/test_v2/test/TEST_19186.jpg
# ./handwriting-recognition/test_v2/test/TEST_7588.jpg
# ./handwriting-recognition/test_v2/test/TEST_36165.jpg
# ./handwriting-recognition/test_v2/test/TEST_21419.jpg
# ./handwriting-recognition/test_v2/test/TEST_39256.jpg
# ./handwriting-recognition/test_v2/test/TEST_26376.jpg
# ./handwriting-recognition/test_v2/test/TEST_29045.jpg
# ./handwriting-recognition/test_v2/test/TEST_27068.jpg
# ./handwriting-recognition/test_v2/test/TEST_30514.jpg
# ./handwriting-recognition/test_v2/test/TEST_8863.jpg
# ./handwriting-recognition/test_v2/test/TEST_6696.jpg
# ./handwriting-recognition/test_v2/test/TEST_18298.jpg
# ./handwriting-recognition/test_v2/test/TEST_38148.jpg
# ./handwriting-recognition/test_v2/test/TEST_20707.jpg
# ./handwriting-recognition/test_v2/test/TEST_3936.jpg
# ./handwriting-recognition/test_v2/test/TEST_34772.jpg
# ./handwriting-recognition/test_v2/test/TEST_15964.jpg
# ./handwriting-recognition/test_v2/test/TEST_24561.jpg
# ./handwriting-recognition/test_v2/test/TEST_32303.jpg
# ./handwriting-recognition/test_v2/test/TEST_22110.jpg
# ./handwriting-recognition/test_v2/test/TEST_4081.jpg
# ./handwriting-recognition/test_v2/test/TEST_3922.jpg
# ./handwriting-recognition/test_v2/test/TEST_34766.jpg
# ./handwriting-recognition/test_v2/test/TEST_33009.jpg
# ./handwriting-recognition/test_v2/test/TEST_15970.jpg
# ./handwriting-recognition/test_v2/test/TEST_24575.jpg
# ./handwriting-recognition/test_v2/test/TEST_32317.jpg
# ./handwriting-recognition/test_v2/test/TEST_22104.jpg
# ./handwriting-recognition/test_v2/test/TEST_4095.jpg
# ./handwriting-recognition/test_v2/test/TEST_35478.jpg
# ./handwriting-recognition/test_v2/test/TEST_10808.jpg
# ./handwriting-recognition/test_v2/test/TEST_36171.jpg
# ./handwriting-recognition/test_v2/test/TEST_19192.jpg
# ./handwriting-recognition/test_v2/test/TEST_39242.jpg
# ./handwriting-recognition/test_v2/test/TEST_26362.jpg
# ./handwriting-recognition/test_v2/test/TEST_29051.jpg
# ./handwriting-recognition/test_v2/test/TEST_8877.jpg
# ./handwriting-recognition/test_v2/test/TEST_30500.jpg
# ./handwriting-recognition/test_v2/test/TEST_6682.jpg
# ./handwriting-recognition/test_v2/test/TEST_20713.jpg
# ./handwriting-recognition/test_v2/test/TEST_37509.jpg
# ./handwriting-recognition/test_v2/test/TEST_40959.jpg
# ./handwriting-recognition/test_v2/test/TEST_20075.jpg
# ./handwriting-recognition/test_v2/test/TEST_28429.jpg
# ./handwriting-recognition/test_v2/test/TEST_30266.jpg
# ./handwriting-recognition/test_v2/test/TEST_26404.jpg
# ./handwriting-recognition/test_v2/test/TEST_0595.jpg
# ./handwriting-recognition/test_v2/test/TEST_31178.jpg
# ./handwriting-recognition/test_v2/test/TEST_40781.jpg
# ./handwriting-recognition/test_v2/test/TEST_17801.jpg
# ./handwriting-recognition/test_v2/test/TEST_29737.jpg
# ./handwriting-recognition/test_v2/test/TEST_36617.jpg
# ./handwriting-recognition/test_v2/test/TEST_39524.jpg
# ./handwriting-recognition/test_v2/test/TEST_1853.jpg
# ./handwriting-recognition/test_v2/test/TEST_22662.jpg
# ./handwriting-recognition/test_v2/test/TEST_32471.jpg
# ./handwriting-recognition/test_v2/test/TEST_2382.jpg
# ./handwriting-recognition/test_v2/test/TEST_24213.jpg
# ./handwriting-recognition/test_v2/test/TEST_12979.jpg
# ./handwriting-recognition/test_v2/test/TEST_34000.jpg
# ./handwriting-recognition/test_v2/test/TEST_13454.jpg
# ./handwriting-recognition/test_v2/test/TEST_2369.jpg
# ./handwriting-recognition/test_v2/test/TEST_33784.jpg
# ./handwriting-recognition/test_v2/test/TEST_22851.jpg
# ./handwriting-recognition/test_v2/test/TEST_12992.jpg
# ./handwriting-recognition/test_v2/test/TEST_5406.jpg
# ./handwriting-recognition/test_v2/test/TEST_23597.jpg
# ./handwriting-recognition/test_v2/test/TEST_4718.jpg
# ./handwriting-recognition/test_v2/test/TEST_22689.jpg
# ./handwriting-recognition/test_v2/test/TEST_15025.jpg
# ./handwriting-recognition/test_v2/test/TEST_3077.jpg
# ./handwriting-recognition/test_v2/test/TEST_31193.jpg
# ./handwriting-recognition/test_v2/test/TEST_38809.jpg
# ./handwriting-recognition/test_v2/test/TEST_11243.jpg
# ./handwriting-recognition/test_v2/test/TEST_8122.jpg
# ./handwriting-recognition/test_v2/test/TEST_21380.jpg
# ./handwriting-recognition/test_v2/test/TEST_27929.jpg
# ./handwriting-recognition/test_v2/test/TEST_7211.jpg
# ./handwriting-recognition/test_v2/test/TEST_17632.jpg
# ./handwriting-recognition/test_v2/test/TEST_29904.jpg
# ./handwriting-recognition/test_v2/test/TEST_18501.jpg
# ./handwriting-recognition/test_v2/test/TEST_1660.jpg
# ./handwriting-recognition/test_v2/test/TEST_36824.jpg
# ./handwriting-recognition/test_v2/test/TEST_41312.jpg
# ./handwriting-recognition/test_v2/test/TEST_1106.jpg
# ./handwriting-recognition/test_v2/test/TEST_27097.jpg
# ./handwriting-recognition/test_v2/test/TEST_17154.jpg
# ./handwriting-recognition/test_v2/test/TEST_18267.jpg
# ./handwriting-recognition/test_v2/test/TEST_6669.jpg
# ./handwriting-recognition/test_v2/test/TEST_37284.jpg
# ./handwriting-recognition/test_v2/test/TEST_8644.jpg
# ./handwriting-recognition/test_v2/test/TEST_7577.jpg
# ./handwriting-recognition/test_v2/test/TEST_19179.jpg
# ./handwriting-recognition/test_v2/test/TEST_20920.jpg
# ./handwriting-recognition/test_v2/test/TEST_0218.jpg
# ./handwriting-recognition/test_v2/test/TEST_26389.jpg
# ./handwriting-recognition/test_v2/test/TEST_11525.jpg
# ./handwriting-recognition/test_v2/test/TEST_25680.jpg
# ./handwriting-recognition/test_v2/test/TEST_34955.jpg
# ./handwriting-recognition/test_v2/test/TEST_3711.jpg
# ./handwriting-recognition/test_v2/test/TEST_35493.jpg
# ./handwriting-recognition/test_v2/test/TEST_15743.jpg
# ./handwriting-recognition/test_v2/test/TEST_5360.jpg
# ./handwriting-recognition/test_v2/test/TEST_25858.jpg
# ./handwriting-recognition/test_v2/test/TEST_13332.jpg
# ./handwriting-recognition/test_v2/test/TEST_34941.jpg
# ./handwriting-recognition/test_v2/test/TEST_25694.jpg
# ./handwriting-recognition/test_v2/test/TEST_12038.jpg
# ./handwriting-recognition/test_v2/test/TEST_3705.jpg
# ./handwriting-recognition/test_v2/test/TEST_35487.jpg
# ./handwriting-recognition/test_v2/test/TEST_15757.jpg
# ./handwriting-recognition/test_v2/test/TEST_5374.jpg
# ./handwriting-recognition/test_v2/test/TEST_34799.jpg
# ./handwriting-recognition/test_v2/test/TEST_14449.jpg
# ./handwriting-recognition/test_v2/test/TEST_13326.jpg
# ./handwriting-recognition/test_v2/test/TEST_1112.jpg
# ./handwriting-recognition/test_v2/test/TEST_41306.jpg
# ./handwriting-recognition/test_v2/test/TEST_8888.jpg
# ./handwriting-recognition/test_v2/test/TEST_27083.jpg
# ./handwriting-recognition/test_v2/test/TEST_17140.jpg
# ./handwriting-recognition/test_v2/test/TEST_31839.jpg
# ./handwriting-recognition/test_v2/test/TEST_37290.jpg
# ./handwriting-recognition/test_v2/test/TEST_18273.jpg
# ./handwriting-recognition/test_v2/test/TEST_8650.jpg
# ./handwriting-recognition/test_v2/test/TEST_7563.jpg
# ./handwriting-recognition/test_v2/test/TEST_40018.jpg
# ./handwriting-recognition/test_v2/test/TEST_20934.jpg
# ./handwriting-recognition/test_v2/test/TEST_11531.jpg
# ./handwriting-recognition/test_v2/test/TEST_31187.jpg
# ./handwriting-recognition/test_v2/test/TEST_11257.jpg
# ./handwriting-recognition/test_v2/test/TEST_21394.jpg
# ./handwriting-recognition/test_v2/test/TEST_8136.jpg
# ...
# ./handwriting-recognition/test_v2/test/TEST_39688.jpg
# ./handwriting-recognition/test_v2/test/TEST_19558.jpg
# ./handwriting-recognition/test_v2/test/TEST_7156.jpg
# ./handwriting-recognition/test_v2/test/TEST_17561.jpg
# ./handwriting-recognition/test_v2/test/TEST_38582.jpg
# ./handwriting-recognition/test_v2/test/TEST_26964.jpg
# ./handwriting-recognition/test_v2/test/TEST_18652.jpg
# ./handwriting-recognition/test_v2/test/TEST_28791.jpg
# ./handwriting-recognition/test_v2/test/TEST_39844.jpg
# ./handwriting-recognition/test_v2/test/TEST_1533.jpg
# ./handwriting-recognition/test_v2/test/TEST_40439.jpg
# ./handwriting-recognition/test_v2/test/TEST_37869.jpg
# ./handwriting-recognition/test_v2/test/TEST_11110.jpg
# ./handwriting-recognition/test_v2/test/TEST_8271.jpg
# ./handwriting-recognition/test_v2/test/TEST_28949.jpg
# ./handwriting-recognition/test_v2/test/TEST_7142.jpg
# ./handwriting-recognition/test_v2/test/TEST_15376.jpg
# ./handwriting-recognition/test_v2/test/TEST_12419.jpg
# ./handwriting-recognition/test_v2/test/TEST_3324.jpg
# ./handwriting-recognition/test_v2/test/TEST_13707.jpg
# ./handwriting-recognition/test_v2/test/TEST_5755.jpg
# ./handwriting-recognition/test_v2/test/TEST_14068.jpg
# ./handwriting-recognition/test_v2/test/TEST_32911.jpg
# ./handwriting-recognition/test_v2/test/TEST_5033.jpg
# ./handwriting-recognition/test_v2/test/TEST_35918.jpg
# ./handwriting-recognition/test_v2/test/TEST_13061.jpg
# ./handwriting-recognition/test_v2/test/TEST_3442.jpg
# ./handwriting-recognition/test_v2/test/TEST_24815.jpg
# ./handwriting-recognition/test_v2/test/TEST_2984.jpg
# ./handwriting-recognition/test_v2/test/TEST_15410.jpg
# ./handwriting-recognition/test_v2/test/TEST_16119.jpg
# ./handwriting-recognition/test_v2/test/TEST_8517.jpg
# ./handwriting-recognition/test_v2/test/TEST_30860.jpg
# ./handwriting-recognition/test_v2/test/TEST_7624.jpg
# ./handwriting-recognition/test_v2/test/TEST_11676.jpg
# ./handwriting-recognition/test_v2/test/TEST_1255.jpg
# ./handwriting-recognition/test_v2/test/TEST_41041.jpg
# ./handwriting-recognition/test_v2/test/TEST_10568.jpg
# ./handwriting-recognition/test_v2/test/TEST_9609.jpg
# ./handwriting-recognition/test_v2/test/TEST_17207.jpg
# ./handwriting-recognition/test_v2/test/TEST_18134.jpg
# ./handwriting-recognition/test_v2/test/TEST_14726.jpg
# ./handwriting-recognition/test_v2/test/TEST_2774.jpg
# ./handwriting-recognition/test_v2/test/TEST_33399.jpg
# ./handwriting-recognition/test_v2/test/TEST_13049.jpg
# ./handwriting-recognition/test_v2/test/TEST_35930.jpg
# ./handwriting-recognition/test_v2/test/TEST_32087.jpg
# ./handwriting-recognition/test_v2/test/TEST_12357.jpg
# ./handwriting-recognition/test_v2/test/TEST_15438.jpg
# ./handwriting-recognition/test_v2/test/TEST_22294.jpg
# ./handwriting-recognition/test_v2/test/TEST_4305.jpg
# ./handwriting-recognition/test_v2/test/TEST_19202.jpg
# ./handwriting-recognition/test_v2/test/TEST_30848.jpg
# ./handwriting-recognition/test_v2/test/TEST_16131.jpg
# ./handwriting-recognition/test_v2/test/TEST_0163.jpg
# ./handwriting-recognition/test_v2/test/TEST_40377.jpg
# ./handwriting-recognition/test_v2/test/TEST_10540.jpg
# ./handwriting-recognition/test_v2/test/TEST_41069.jpg
# ./handwriting-recognition/test_v2/test/TEST_30690.jpg
# ./handwriting-recognition/test_v2/test/TEST_21945.jpg
# ./handwriting-recognition/test_v2/test/TEST_11886.jpg
# ./handwriting-recognition/test_v2/test/TEST_6512.jpg
# ./handwriting-recognition/test_v2/test/TEST_9621.jpg
# ./handwriting-recognition/test_v2/test/TEST_20483.jpg
# ./handwriting-recognition/test_v2/test/TEST_6274.jpg
# ./handwriting-recognition/test_v2/test/TEST_37699.jpg
# ./handwriting-recognition/test_v2/test/TEST_17549.jpg
# ./handwriting-recognition/test_v2/test/TEST_9147.jpg
# ./handwriting-recognition/test_v2/test/TEST_10226.jpg
# ./handwriting-recognition/test_v2/test/TEST_11138.jpg
# ./handwriting-recognition/test_v2/test/TEST_26794.jpg
# ./handwriting-recognition/test_v2/test/TEST_37841.jpg
# ./handwriting-recognition/test_v2/test/TEST_0605.jpg
# ./handwriting-recognition/test_v2/test/TEST_40411.jpg
# ./handwriting-recognition/test_v2/test/TEST_36587.jpg
# ./handwriting-recognition/test_v2/test/TEST_19564.jpg
# ./handwriting-recognition/test_v2/test/TEST_28961.jpg
# ./handwriting-recognition/test_v2/test/TEST_8259.jpg
# ./handwriting-recognition/test_v2/test/TEST_16657.jpg
# ./handwriting-recognition/test_v2/test/TEST_4463.jpg
# ./handwriting-recognition/test_v2/test/TEST_23834.jpg
# ./handwriting-recognition/test_v2/test/TEST_12431.jpg
# ./handwriting-recognition/test_v2/test/TEST_2012.jpg
# ./handwriting-recognition/test_v2/test/TEST_24183.jpg
# ./handwriting-recognition/test_v2/test/TEST_32939.jpg
# ./handwriting-recognition/test_v2/test/TEST_14040.jpg
# ./handwriting-recognition/test_v2/test/TEST_34390.jpg
# ./handwriting-recognition/test_v2/test/TEST_4477.jpg
# ./handwriting-recognition/test_v2/test/TEST_3318.jpg
# ./handwriting-recognition/test_v2/test/TEST_23820.jpg
# ./handwriting-recognition/test_v2/test/TEST_12425.jpg
# ./handwriting-recognition/test_v2/test/TEST_25289.jpg
# ./handwriting-recognition/test_v2/test/TEST_2006.jpg
# ./handwriting-recognition/test_v2/test/TEST_24197.jpg
# ./handwriting-recognition/test_v2/test/TEST_14054.jpg
# ./handwriting-recognition/test_v2/test/TEST_5769.jpg
# ./handwriting-recognition/test_v2/test/TEST_34384.jpg
# ./handwriting-recognition/test_v2/test/TEST_26958.jpg
# ./handwriting-recognition/test_v2/test/TEST_6260.jpg
# ./handwriting-recognition/test_v2/test/TEST_9153.jpg
# ./handwriting-recognition/test_v2/test/TEST_10232.jpg
# ./handwriting-recognition/test_v2/test/TEST_39878.jpg
# ./handwriting-recognition/test_v2/test/TEST_37855.jpg
# ./handwriting-recognition/test_v2/test/TEST_26780.jpg
# ./handwriting-recognition/test_v2/test/TEST_40405.jpg
# ./handwriting-recognition/test_v2/test/TEST_0611.jpg
# ./handwriting-recognition/test_v2/test/TEST_19570.jpg
# ./handwriting-recognition/test_v2/test/TEST_36593.jpg
# ./handwriting-recognition/test_v2/test/TEST_16643.jpg
# ./handwriting-recognition/test_v2/test/TEST_28975.jpg
# ./handwriting-recognition/test_v2/test/TEST_7618.jpg
# ./handwriting-recognition/test_v2/test/TEST_19216.jpg
# ./handwriting-recognition/test_v2/test/TEST_16125.jpg
# ./handwriting-recognition/test_v2/test/TEST_21789.jpg
# ./handwriting-recognition/test_v2/test/TEST_40363.jpg
# ./handwriting-recognition/test_v2/test/TEST_0177.jpg
# ./handwriting-recognition/test_v2/test/TEST_10554.jpg
# ./handwriting-recognition/test_v2/test/TEST_21951.jpg
# ./handwriting-recognition/test_v2/test/TEST_1269.jpg
# ./handwriting-recognition/test_v2/test/TEST_30684.jpg
# ./handwriting-recognition/test_v2/test/TEST_18108.jpg
# ./handwriting-recognition/test_v2/test/TEST_6506.jpg
# ./handwriting-recognition/test_v2/test/TEST_11892.jpg
# ./handwriting-recognition/test_v2/test/TEST_20497.jpg
# ./handwriting-recognition/test_v2/test/TEST_9635.jpg
# ./handwriting-recognition/test_v2/test/TEST_14732.jpg
# ./handwriting-recognition/test_v2/test/TEST_2760.jpg
# ./handwriting-recognition/test_v2/test/TEST_35924.jpg
# ./handwriting-recognition/test_v2/test/TEST_32093.jpg
# ./handwriting-recognition/test_v2/test/TEST_12343.jpg
# ./handwriting-recognition/test_v2/test/TEST_22280.jpg
# ./handwriting-recognition/test_v2/test/TEST_4311.jpg
# ./handwriting-recognition/test_v2/test/TEST_24829.jpg
# ./handwriting-recognition/test_v2/test/TEST_25504.jpg
# ./handwriting-recognition/test_v2/test/TEST_14901.jpg
# ./handwriting-recognition/test_v2/test/TEST_3495.jpg
# ./handwriting-recognition/test_v2/test/TEST_32078.jpg
# ./handwriting-recognition/test_v2/test/TEST_35717.jpg
# ./handwriting-recognition/test_v2/test/TEST_2953.jpg
# ./handwriting-recognition/test_v2/test/TEST_34409.jpg
# ./handwriting-recognition/test_v2/test/TEST_23175.jpg
# ./handwriting-recognition/test_v2/test/TEST_33366.jpg
# ./handwriting-recognition/test_v2/test/TEST_28020.jpg
# ./handwriting-recognition/test_v2/test/TEST_1282.jpg
# ./handwriting-recognition/test_v2/test/TEST_41096.jpg
# ./handwriting-recognition/test_v2/test/TEST_27313.jpg
# ./handwriting-recognition/test_v2/test/TEST_38233.jpg
# ./handwriting-recognition/test_v2/test/TEST_37100.jpg
# ./handwriting-recognition/test_v2/test/TEST_11879.jpg
# ./handwriting-recognition/test_v2/test/TEST_21762.jpg
# ./handwriting-recognition/test_v2/test/TEST_31571.jpg
# ./handwriting-recognition/test_v2/test/TEST_40388.jpg
# ./handwriting-recognition/test_v2/test/TEST_9806.jpg
# ./handwriting-recognition/test_v2/test/TEST_31217.jpg
# ./handwriting-recognition/test_v2/test/TEST_29458.jpg
# ./handwriting-recognition/test_v2/test/TEST_21004.jpg
# ./handwriting-recognition/test_v2/test/TEST_7195.jpg
# ./handwriting-recognition/test_v2/test/TEST_36578.jpg
# ./handwriting-recognition/test_v2/test/TEST_0822.jpg
# ./handwriting-recognition/test_v2/test/TEST_38555.jpg
# ./handwriting-recognition/test_v2/test/TEST_37666.jpg
# ./handwriting-recognition/test_v2/test/TEST_18685.jpg
# ./handwriting-recognition/test_v2/test/TEST_16870.jpg
# ./handwriting-recognition/test_v2/test/TEST_39893.jpg
# ./handwriting-recognition/test_v2/test/TEST_28746.jpg
# ./handwriting-recognition/test_v2/test/TEST_30109.jpg
# ./handwriting-recognition/test_v2/test/TEST_27475.jpg
# ./handwriting-recognition/test_v2/test/TEST_33400.jpg
# ./handwriting-recognition/test_v2/test/TEST_5782.jpg
# ./handwriting-recognition/test_v2/test/TEST_23613.jpg
# ./handwriting-recognition/test_v2/test/TEST_35071.jpg
# ./handwriting-recognition/test_v2/test/TEST_13908.jpg
# ./handwriting-recognition/test_v2/test/TEST_25262.jpg
# ./handwriting-recognition/test_v2/test/TEST_24168.jpg
# ./handwriting-recognition/test_v2/test/TEST_33414.jpg
# ./handwriting-recognition/test_v2/test/TEST_5796.jpg
# ./handwriting-recognition/test_v2/test/TEST_23607.jpg
# ./handwriting-recognition/test_v2/test/TEST_4488.jpg
# ./handwriting-recognition/test_v2/test/TEST_35065.jpg
# ./handwriting-recognition/test_v2/test/TEST_22519.jpg
# ./handwriting-recognition/test_v2/test/TEST_25276.jpg
# ./handwriting-recognition/test_v2/test/TEST_31203.jpg
# ./handwriting-recognition/test_v2/test/TEST_18849.jpg
# ./handwriting-recognition/test_v2/test/TEST_21010.jpg
# ./handwriting-recognition/test_v2/test/TEST_7181.jpg
# ./handwriting-recognition/test_v2/test/TEST_38541.jpg
# ./handwriting-recognition/test_v2/test/TEST_0836.jpg
# ./handwriting-recognition/test_v2/test/TEST_18691.jpg
# ./handwriting-recognition/test_v2/test/TEST_37672.jpg
# ./handwriting-recognition/test_v2/test/TEST_28752.jpg
# ./handwriting-recognition/test_v2/test/TEST_39887.jpg
# ./handwriting-recognition/test_v2/test/TEST_16864.jpg
# ./handwriting-recognition/test_v2/test/TEST_27461.jpg
# ./handwriting-recognition/test_v2/test/TEST_41082.jpg
# ./handwriting-recognition/test_v2/test/TEST_1296.jpg
# ./handwriting-recognition/test_v2/test/TEST_28034.jpg
# ./handwriting-recognition/test_v2/test/TEST_27307.jpg
# ./handwriting-recognition/test_v2/test/TEST_38227.jpg
# ./handwriting-recognition/test_v2/test/TEST_20468.jpg
# ./handwriting-recognition/test_v2/test/TEST_37114.jpg
# ./handwriting-recognition/test_v2/test/TEST_21776.jpg
# ./handwriting-recognition/test_v2/test/TEST_39139.jpg
# ./handwriting-recognition/test_v2/test/TEST_9812.jpg
# ./handwriting-recognition/test_v2/test/TEST_0188.jpg
# ./handwriting-recognition/test_v2/test/TEST_31565.jpg
# ./handwriting-recognition/test_v2/test/TEST_26019.jpg
# ./handwriting-recognition/test_v2/test/TEST_25510.jpg
# ./handwriting-recognition/test_v2/test/TEST_3481.jpg
# ./handwriting-recognition/test_v2/test/TEST_14915.jpg
# ./handwriting-recognition/test_v2/test/TEST_35703.jpg
# ./handwriting-recognition/test_v2/test/TEST_2947.jpg
# ./handwriting-recognition/test_v2/test/TEST_23161.jpg
# ./handwriting-recognition/test_v2/test/TEST_33372.jpg
# ./handwriting-recognition/test_v2/test/TEST_10583.jpg
# ./handwriting-recognition/test_v2/test/TEST_7817.jpg
# ./handwriting-recognition/test_v2/test/TEST_30653.jpg
# ./handwriting-recognition/test_v2/test/TEST_21986.jpg
# ./handwriting-recognition/test_v2/test/TEST_11845.jpg
# ./handwriting-recognition/test_v2/test/TEST_20440.jpg
# ./handwriting-recognition/test_v2/test/TEST_36222.jpg
# ./handwriting-recognition/test_v2/test/TEST_39111.jpg
# ./handwriting-recognition/test_v2/test/TEST_26031.jpg
# ./handwriting-recognition/test_v2/test/TEST_29302.jpg
# ./handwriting-recognition/test_v2/test/TEST_32044.jpg
# ./handwriting-recognition/test_v2/test/TEST_12394.jpg
# ./handwriting-recognition/test_v2/test/TEST_25538.jpg
# ./handwriting-recognition/test_v2/test/TEST_22257.jpg
# ./handwriting-recognition/test_v2/test/TEST_23149.jpg
# ./handwriting-recognition/test_v2/test/TEST_34435.jpg
# ./handwriting-recognition/test_v2/test/TEST_24626.jpg
# ./handwriting-recognition/test_v2/test/TEST_24140.jpg
# ./handwriting-recognition/test_v2/test/TEST_14083.jpg
# ./handwriting-recognition/test_v2/test/TEST_34353.jpg
# ./handwriting-recognition/test_v2/test/TEST_22531.jpg
# ./handwriting-recognition/test_v2/test/TEST_13934.jpg
# ./handwriting-recognition/test_v2/test/TEST_32722.jpg
# ./handwriting-recognition/test_v2/test/TEST_5966.jpg
# ./handwriting-recognition/test_v2/test/TEST_26757.jpg
# ./handwriting-recognition/test_v2/test/TEST_18861.jpg
# ./handwriting-recognition/test_v2/test/TEST_37882.jpg
# ./handwriting-recognition/test_v2/test/TEST_29464.jpg
# ./handwriting-recognition/test_v2/test/TEST_36544.jpg
# ./handwriting-recognition/test_v2/test/TEST_39677.jpg
# ./handwriting-recognition/test_v2/test/TEST_16694.jpg
# ./handwriting-recognition/test_v2/test/TEST_21038.jpg
# ./handwriting-recognition/test_v2/test/TEST_20326.jpg
# ./handwriting-recognition/test_v2/test/TEST_9184.jpg
# ./handwriting-recognition/test_v2/test/TEST_38569.jpg
# ./handwriting-recognition/test_v2/test/TEST_27449.jpg
# ./handwriting-recognition/test_v2/test/TEST_30135.jpg
# ./handwriting-recognition/test_v2/test/TEST_37896.jpg
# ./handwriting-recognition/test_v2/test/TEST_18875.jpg
# ./handwriting-recognition/test_v2/test/TEST_26743.jpg
# ./handwriting-recognition/test_v2/test/TEST_29470.jpg
# ./handwriting-recognition/test_v2/test/TEST_36550.jpg
# ./handwriting-recognition/test_v2/test/TEST_16680.jpg
# ./handwriting-recognition/test_v2/test/TEST_39663.jpg
# ./handwriting-recognition/test_v2/test/TEST_9190.jpg
# ./handwriting-recognition/test_v2/test/TEST_20332.jpg
# ./handwriting-recognition/test_v2/test/TEST_30121.jpg
# ./handwriting-recognition/test_v2/test/TEST_16858.jpg
# ./handwriting-recognition/test_v2/test/TEST_33428.jpg
# ./handwriting-recognition/test_v2/test/TEST_24154.jpg
# ./handwriting-recognition/test_v2/test/TEST_14097.jpg
# ./handwriting-recognition/test_v2/test/TEST_34347.jpg
# ./handwriting-recognition/test_v2/test/TEST_15389.jpg
# ./handwriting-recognition/test_v2/test/TEST_22525.jpg
# ./handwriting-recognition/test_v2/test/TEST_13920.jpg
# ./handwriting-recognition/test_v2/test/TEST_35059.jpg
# ./handwriting-recognition/test_v2/test/TEST_32736.jpg
# ./handwriting-recognition/test_v2/test/TEST_5972.jpg
# ./handwriting-recognition/test_v2/test/TEST_32050.jpg
# ./handwriting-recognition/test_v2/test/TEST_14929.jpg
# ./handwriting-recognition/test_v2/test/TEST_12380.jpg
# ./handwriting-recognition/test_v2/test/TEST_22243.jpg
# ./handwriting-recognition/test_v2/test/TEST_34421.jpg
# ./handwriting-recognition/test_v2/test/TEST_24632.jpg
# ./handwriting-recognition/test_v2/test/TEST_7803.jpg
# ./handwriting-recognition/test_v2/test/TEST_10597.jpg
# ./handwriting-recognition/test_v2/test/TEST_21992.jpg
# ./handwriting-recognition/test_v2/test/TEST_30647.jpg
# ./handwriting-recognition/test_v2/test/TEST_28008.jpg
# ./handwriting-recognition/test_v2/test/TEST_11851.jpg
# ./handwriting-recognition/test_v2/test/TEST_37128.jpg
# ./handwriting-recognition/test_v2/test/TEST_20454.jpg
# ./handwriting-recognition/test_v2/test/TEST_36236.jpg
# ./handwriting-recognition/test_v2/test/TEST_39105.jpg
# ./handwriting-recognition/test_v2/test/TEST_11689.jpg
# ./handwriting-recognition/test_v2/test/TEST_26025.jpg
# ./handwriting-recognition/test_v2/test/TEST_29316.jpg
# ./handwriting-recognition/test_v2/test/TEST_31559.jpg
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %%
train_df = pd.read_csv('./handwriting-recognition/written_name_train_v2.csv')
train_df
# Out:
#                 FILENAME       IDENTITY
# 0        TRAIN_00001.jpg      BALTHAZAR
# 1        TRAIN_00002.jpg          SIMON
# 2        TRAIN_00003.jpg          BENES
# 3        TRAIN_00004.jpg        LA LOVE
# 4        TRAIN_00005.jpg         DAPHNE
# ...                  ...            ...
# 330956  TRAIN_330957.jpg          LENNY
# 330957  TRAIN_330958.jpg        TIFFANY
# 330958  TRAIN_330959.jpg  COUTINHO DESA
# 330959  TRAIN_330960.jpg         MOURAD
# 330960  TRAIN_330961.jpg        HELOISE
#
# [330961 rows x 2 columns]

# %%
print("There are total",len(train_df['IDENTITY'].unique()),"unique  signatures.")
train_df['IDENTITY'].value_counts()
# Out:
# There are total 100540 unique  signatures.
# IDENTITY
# THOMAS           1825
# EMPTY            1796
# LEA              1582
# EMMA             1482
# LUCAS            1479
#                  ...
# DE METZ             1
# SCHOPPMANN          1
# SCHNITZLER          1
# HELYIL              1
# COUTINHO DESA       1
# Name: count, Length: 100539, dtype: int64

# %%
# j = 5
# for i,img_path in enumerate(train_df[train_df['IDENTITY']=="THOMAS"]["FILENAME"]):
#     image = io.imread('./handwriting-recognition/train_v2/train/'+img_path)
#     io.imshow(image)
#     io.show()
#     print(img_path)
#     if i > j:
#         break

# %%
train_df.isna().sum()
# Out:
# FILENAME      0
# IDENTITY    565
# dtype: int64

# %%
train_df.dropna(inplace=True)
train_df.reset_index(drop=True, inplace=True)
train_df
# Out:
#                 FILENAME       IDENTITY
# 0        TRAIN_00001.jpg      BALTHAZAR
# 1        TRAIN_00002.jpg          SIMON
# 2        TRAIN_00003.jpg          BENES
# 3        TRAIN_00004.jpg        LA LOVE
# 4        TRAIN_00005.jpg         DAPHNE
# ...                  ...            ...
# 330391  TRAIN_330957.jpg          LENNY
# 330392  TRAIN_330958.jpg        TIFFANY
# 330393  TRAIN_330959.jpg  COUTINHO DESA
# 330394  TRAIN_330960.jpg         MOURAD
# 330395  TRAIN_330961.jpg        HELOISE
#
# [330396 rows x 2 columns]

# %%
test_df = pd.read_csv('./handwriting-recognition/written_name_test_v2.csv')
test_df.head(5)
# Out:
#         FILENAME  IDENTITY
# 0  TEST_0001.jpg     KEVIN
# 1  TEST_0002.jpg  CLOTAIRE
# 2  TEST_0003.jpg      LENA
# 3  TEST_0004.jpg     JULES
# 4  TEST_0005.jpg   CHERPIN

# %%
test_df['IDENTITY'].value_counts()
# Out:
# IDENTITY
# THOMAS        227
# EMPTY         221
# EMMA          202
# LEA           200
# HUGO          187
#              ...
# KIFANI          1
# AOUINI          1
# VINCENS         1
# DE MIRANDA      1
# MELAB           1
# Name: count, Length: 20279, dtype: int64

# %%
test_df.isna().sum()
# Out:
# FILENAME     0
# IDENTITY    70
# dtype: int64

# %%
test_df.dropna(inplace=True)
test_df.reset_index(drop=True, inplace=True)
test_df
# Out:
#              FILENAME       IDENTITY
# 0       TEST_0001.jpg          KEVIN
# 1       TEST_0002.jpg       CLOTAIRE
# 2       TEST_0003.jpg           LENA
# 3       TEST_0004.jpg          JULES
# 4       TEST_0005.jpg        CHERPIN
# ...               ...            ...
# 41295  TEST_41366.jpg        ALEXANE
# 41296  TEST_41367.jpg  PEREIRA-SILVA
# 41297  TEST_41368.jpg        LAURENT
# 41298  TEST_41369.jpg       DEFFENSE
# 41299  TEST_41370.jpg          MELAB
#
# [41300 rows x 2 columns]

# %%
val_df = pd.read_csv('./handwriting-recognition/written_name_validation_v2.csv')
val_df.head(5)
# Out:
#               FILENAME    IDENTITY
# 0  VALIDATION_0001.jpg       BILEL
# 1  VALIDATION_0002.jpg  LAUMIONIER
# 2  VALIDATION_0003.jpg         LEA
# 3  VALIDATION_0004.jpg   JEAN-ROCH
# 4  VALIDATION_0005.jpg        RUPP

# %%
val_df['IDENTITY'].value_counts()
# Out:
# IDENTITY
# THOMAS     219
# LEA        204
# LUCAS      195
# EMPTY      187
# EMMA       186
#           ...
# ROIGNA       1
# VULLIEZ      1
# OUAZAN       1
# BUFF         1
# MARWANE      1
# Name: count, Length: 20227, dtype: int64

# %%
val_df.isna().sum()
# Out:
# FILENAME     0
# IDENTITY    78
# dtype: int64

# %%
val_df.dropna(inplace=True)
val_df.reset_index(drop=True, inplace=True)
val_df
# Out:
#                    FILENAME    IDENTITY
# 0       VALIDATION_0001.jpg       BILEL
# 1       VALIDATION_0002.jpg  LAUMIONIER
# 2       VALIDATION_0003.jpg         LEA
# 3       VALIDATION_0004.jpg   JEAN-ROCH
# 4       VALIDATION_0005.jpg        RUPP
# ...                     ...         ...
# 41287  VALIDATION_41366.jpg    CHAILLAN
# 41288  VALIDATION_41367.jpg      BAROUH
# 41289  VALIDATION_41368.jpg     MAXENCE
# 41290  VALIDATION_41369.jpg     HAMELIN
# 41291  VALIDATION_41370.jpg        LOLA
#
# [41292 rows x 2 columns]

# %%
from skimage import io
image = io.imread('./handwriting-recognition/train_v2/train/TRAIN_00001.jpg')
io.imshow(image)
io.show()

# %%
image.shape
# Out:
# (50, 284, 3)

# %%
import torchvision.datasets as datasets
import torchvision.transforms as transforms
from torch.utils.data import Dataset, DataLoader
import string
from PIL import Image

# %%
class CustomDataset(Dataset):
    def __init__(self,image_path, dataframe,transform=None, target_transform=None):
        self.df = dataframe
        self.image_path = image_path
        self.transform =transform
    def __len__(self):
        return len(self.df)
    def __getitem__(self,idx):
        image_filepath = os.path.join(self.image_path+self.df['FILENAME'][idx])
        image = Image.open(image_filepath).convert('L')  # Convert to grayscale
        vocab = string.ascii_letters + string.digits + string.punctuation + " "
        char_to_idx = {char: idx for idx, char in enumerate(vocab)}  # char -> index
        idx_to_char = {idx: char for idx, char in enumerate(vocab)}  # index -> char
        max_len = train_df['IDENTITY'].str.len().max()
        label = self.df['IDENTITY'][idx]
        # print(type(label))
        char_to_idx['<PAD>'] = 0
        # print(char_to_idx)
        label_indices = [char_to_idx[str(char)] for char in label]  # Convert to indices
        padded_label = label_indices + [int(char_to_idx['<PAD>'])] * (int(max_len - len(label_indices)))
        if self.transform:
            image = self.transform(image)
        label_tensor = torch.tensor(padded_label,dtype=torch.long).unsqueeze(-1)
        return image,label_tensor,label

# %%
batch_size = 396

# %%
transform = transforms.Compose([
        transforms.Resize((128,128)),
        transforms.ToTensor(),
        transforms.Normalize((0.5,), (0.5,))
    ])
train_image_path = './handwriting-recognition/train_v2/train/'
train_dataset = CustomDataset(train_image_path,train_df,transform=transform)
train_loader = DataLoader(train_dataset,batch_size=batch_size,shuffle=True)

test_image_path = './handwriting-recognition/test_v2/test/'
test_dataset = CustomDataset(test_image_path,test_df,transform=transform)
test_loader = DataLoader(test_dataset,batch_size=batch_size)

val_image_path = './handwriting-recognition/validation_v2/validation/'
val_dataset = CustomDataset(val_image_path,val_df,transform=transform)
val_loader = DataLoader(val_dataset,batch_size=batch_size,shuffle=True)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

num_images = 12
images, label_tensor,label = next(iter(train_loader))
random_images = random.sample(range(len(images)),num_images)
plt.figure(figsize=(12, 8))
rows, cols = 3, 4
for i,img in enumerate(random_images):
    plt.subplot(rows, cols, i + 1)
    plt.imshow(images[img].squeeze(0).numpy())
    plt.title(label[img])

# %%
if not torch.backends.mps.is_available():
    device = torch.device("mps")
elif torch.cuda.is_available():
    device = torch.device("cuda")
else:
    device = "cpu"

# %%
# Generator Network (Conditional GAN Generator)
class HandwritingGenerator(nn.Module):
    def __init__(self, vocab_size, embedding_dim, lstm_hidden_dim, noise_dim, image_size):
        super(HandwritingGenerator, self).__init__()
        
        self.embedding = nn.Embedding(vocab_size, embedding_dim)
        self.lstm = nn.LSTM(embedding_dim, lstm_hidden_dim, batch_first=True)
        self.text_fc = nn.Linear(lstm_hidden_dim, lstm_hidden_dim)
        
        self.fc1 = nn.Linear(lstm_hidden_dim + noise_dim, 512)
        self.fc2 = nn.Linear(512, 1024)
        self.fc3 = nn.Linear(1024, image_size * image_size)
    
    def forward(self, text_input, noise):
        text_input = text_input.squeeze(-1)
        embedded_text = self.embedding(text_input)
    
        _, (hidden, _) = self.lstm(embedded_text)
        text_features = self.text_fc(hidden.squeeze(0))
        
        combined_input = torch.cat([text_features, noise], dim=1)
        x = F.relu(self.fc1(combined_input))
        x = F.relu(self.fc2(x))
        x = torch.tanh(self.fc3(x))
        return x.view(x.size(0), 1, 128, 128)


class HandwritingDiscriminator(nn.Module):
    def __init__(self, vocab_size, embedding_dim, image_size):
        super(HandwritingDiscriminator, self).__init__()
        

        self.embedding = nn.Embedding(vocab_size, embedding_dim)

        self.conv1 = nn.Conv2d(1, 64, kernel_size=4, stride=2, padding=1)  
        self.conv2 = nn.Conv2d(64, 128, kernel_size=4, stride=2, padding=1)
        self.conv3 = nn.Conv2d(128, 256, kernel_size=4, stride=2, padding=1)
        self.conv4 = nn.Conv2d(256, 512, kernel_size=4, stride=2, padding=1) 
        
        self.text_fc = nn.Linear(embedding_dim, 512)
        self.image_fc = nn.Linear(512 * (image_size // 16) * (image_size // 16), 512)
        self.final_fc = nn.Linear(1024, 1)

    def forward(self, image, text_input):
        text_input = text_input.squeeze(-1)
        embedded_text = self.embedding(text_input)
        text_features = torch.mean(embedded_text, dim=1)
        text_features = F.relu(self.text_fc(text_features))

        x = F.leaky_relu(self.conv1(image), 0.2)
        x = F.leaky_relu(self.conv2(x), 0.2)
        x = F.leaky_relu(self.conv3(x), 0.2)
        x = F.leaky_relu(self.conv4(x), 0.2)
        
        x = x.view(x.size(0), -1)
        image_features = F.relu(self.image_fc(x))
        # Step 3: Combine image and text features
        combined_features = torch.cat([image_features, text_features], dim=1)
        
        # Step 4: Classification
        validity = torch.sigmoid(self.final_fc(combined_features))
        return validity

vocab_size = 20227
embedding_dim = 128
noise_dim=100
noise = torch.randn(batch_size, noise_dim).to(device)
generator = HandwritingGenerator(vocab_size,embedding_dim,lstm_hidden_dim=256,noise_dim=noise_dim,image_size=128).to(device)
discriminator = HandwritingDiscriminator(vocab_size,embedding_dim,128).to(device)

# %%
# Optimizers specified in the torch.optim package

generator_optimizer = torch.optim.Adam(generator.parameters(), lr=0.0002,betas=(0.5, 0.999))
criterion = nn.BCELoss()
discriminator_optimizer = torch.optim.Adam(discriminator.parameters(), lr=0.0002, betas=(0.5, 0.999))

# %%
EPOCHS = 10
disc_losses = []
gen_losses = []
best_gen_loss = float('inf')

for epoch in range(EPOCHS):
    for i,data in enumerate(train_loader):
        # print(images.shape,'0')
        images,label_tensor,label = data
        images = images.to(device)

        #Labels
        real_labels = torch.ones(batch_size, 1).to(device)
        fake_labels = torch.zeros(batch_size, 1).to(device)

        # Train discriminator with real images
        discriminator_optimizer.zero_grad()
        real_output = discriminator(images,label_tensor)
        real_loss = criterion(real_output, real_labels)
        
        #Train discriminator with fake image
        fake_image = generator(label_tensor,noise).detach()
        fake_output = discriminator(fake_image,label_tensor)
        fake_loss = criterion(fake_output, fake_labels)

        disc_loss = real_loss + fake_loss
        disc_loss.backward()
        discriminator_optimizer.step()

        #Train Generator
        generator_optimizer.zero_grad()
        fake_labels = torch.ones(batch_size, 1)
        fake_outputs = discriminator(fake_image,label_tensor)
        gen_loss = criterion(fake_outputs, real_labels)
        gen_loss.backward()
        generator_optimizer.step()
        disc_losses.append(disc_loss)
        gen_losses.append(gen_loss)
    if gen_loss.item() < best_gen_loss:
        best_gen_loss = gen_loss.item()
        torch.save(generator.state_dict(), "best_generator.pth")  # Save best generator model
        print(f"New best generator model saved with loss: {best_gen_loss:.4f}")
        
    print(f"Epoch [{epoch+1}/{EPOCHS}], Disc Loss: {disc_loss.item():.4f}, Gen Loss: {gen_loss.item():.4f}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[99], line 18
#      16 # Train discriminator with real images
#      17 discriminator_optimizer.zero_grad()
# ---> 18 real_output = discriminator(images,label_tensor)
#      19 real_loss = criterion(real_output, real_labels)
#      21 #Train discriminator with fake image
#
# File /opt/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File /opt/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# Cell In[92], line 53, in HandwritingDiscriminator.forward(self, image, text_input)
#      51 x = F.leaky_relu(self.conv2(x), 0.2)
#      52 x = F.leaky_relu(self.conv3(x), 0.2)
# ---> 53 x = F.leaky_relu(self.conv4(x), 0.2)
#      55 x = x.view(x.size(0), -1)
#      56 image_features = F.relu(self.image_fc(x))
#
# File /opt/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File /opt/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File /opt/anaconda3/lib/python3.11/site-packages/torch/nn/modules/conv.py:460, in Conv2d.forward(self, input)
#     459 def forward(self, input: Tensor) -> Tensor:
# --> 460     return self._conv_forward(input, self.weight, self.bias)
#
# File /opt/anaconda3/lib/python3.11/site-packages/torch/nn/modules/conv.py:456, in Conv2d._conv_forward(self, input, weight, bias)
#     452 if self.padding_mode != 'zeros':
#     453     return F.conv2d(F.pad(input, self._reversed_padding_repeated_twice, mode=self.padding_mode),
#     454                     weight, bias, self.stride,
#     455                     _pair(0), self.dilation, self.groups)
# --> 456 return F.conv2d(input, weight, bias, self.stride,
#     457                 self.padding, self.dilation, self.groups)
#
# KeyboardInterrupt:

# %%
# !pip install expand-abbreviation
# Out:
# ERROR: Could not find a version that satisfies the requirement expand-abbreviation (from versions: none)
# ERROR: No matching distribution found for expand-abbreviation
#
# [notice] A new release of pip is available: 24.1 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
